# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint

# %%
c=1
# Configure
c = twint.Config()
c.Username = "Persija_Jkt"
#c.Search = "persija"
#c.Pandas = True
c.Since='2021-09-06'
#c.Until='2021-01-15'
#c.Limit = 10000
#c.Lang = "id"
#c.Hide_output = True
c.Store_csv = True
c.Output = "Persija_Jkt 13 sept.csv"

twint.run.Search(c)
# Out:
# 1437270240723816449 2021-09-13 11:21:43 +0700 <Persija_Jkt> “Saya kecewa dengan hasil ini (imbang) karena PSIS mencetak dua gol dengan skema yang sama. Ini akan ada evaluasi. Setelah pertandingan ini pemain harus segera bangkit lagi,” tutur Angelo.  Berita selengkapnya di situs web resmi Persija Jakarta.  #BelieveIn12 #PersijaJakarta  https://t.co/sePNLhQIcL
# 1437240009858318338 2021-09-13 09:21:35 +0700 <Persija_Jkt> Persija Jakarta 2-2 PSIS Semarang  Highlight pertandingan malam tadi saat Macan Kemayoran harus puas dengan hasil imbang kedua dalam lanjutan BRI Liga 1 2021/2022.  🎥: @Indosiar  #BelieveIn12 #PersijaJakarta  https://t.co/U7OsTGC5Gh
# 1437078741532831746 2021-09-12 22:40:46 +0700 <Persija_Jkt> Fulltime. Skor berakhir imbang 2-2.  #PersijaDay #BelieveIn12 #PersijaJakarta  https://t.co/dunMmMI0Hk
# 1437076989731491842 2021-09-12 22:33:48 +0700 <Persija_Jkt> (87') Goal PSIS, Skor 2-2.  #PersijaDay #BelieveIn12 #PersijaJakarta
# ...

# %%
c=1
# Configure
c = twint.Config()
#c.Username = "persija"
c.Search = "persija"
#c.Pandas = True
c.Since='2021-09-06'
#c.Until='2021-01-15'
#c.Limit = 10000
#c.Lang = "id"
#c.Hide_output = True
c.Store_csv = True
c.Output = "persija 13 sept.csv"

twint.run.Search(c)
# Out:
# 1437302353858744321 2021-09-13 13:29:19 +0700 <sidkul_adha> @Persija_Jkt Gimana pelatih gak kecewa. Ngejelasin taktik panjang lebar, teriak" dipinggir lapangan yang dilapangan pada loyo banget. Minta pemain ke management dikasih nya pemaen murahan
# 1437302004162777091 2021-09-13 13:27:56 +0700 <eunjipacarbrian> @kkeday6 Nnti gua bantu persija ngolengin orng yaaa😗😗
# 1437301994679459844 2021-09-13 13:27:53 +0700 <15JVXCAA> @kkeday6 Awalnya dr persija, cmn cowo virgo 1 itu kang ghosting dan diotakku skrg cmn yonk, jd yh jd persib
# 1437301656455049219 2021-09-13 13:26:33 +0700 <D_kustiawan0> #bola Hujan Bantu PSIS Buyarkan Kemenangan Persija  https://t.co/iXEY5vBcC0
# 1437301309711917056 2021-09-13 13:25:10 +0700 <Fakultas_dukun> @Soehandika_ @Persija_Jkt Motta&gt;Riko&gt;Crossing tengah&gt;Motta&gt;Riko&gt;Crossing tengah
# 1437300360322846722 2021-09-13 13:21:24 +0700 <rhezkyerlanda31> @Wahyuarw @Persija_Jkt au ah bete
# ...

# %%
# !instagram-scraper --tag persija -t none  --media-metadata
